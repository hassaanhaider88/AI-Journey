# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("IPL.csv")
df.info()

# %%
df.shape

# %%
print(f"Your rows are {df.shape[0]}, and your columnls are {df.shape[1]}")

# %%
df.isnull().sum()

# %%
match_wins = df["match_winner"].value_counts()

sns.barplot(y=match_wins.index,x=match_wins.values)

# %%
sns.countplot(x = df['toss_decision'])

# %%
count = df[df["toss_winner"]== df["match_winner"]]["match_id"].count()
percentabge = (count *100) / df.shape[0]
percentabge

# %%
# sns.countplot(x = df["won_by"])
df.head()

# %%
sns.barplot(x = df["player_of_the_match"].head(10))

# %%
high_Batter = df.groupby("top_scorer")["highscore"].sum().sort_values(ascending=False).head()
high_Batter.plot(kind = "barh")

# %%
df["high_wickets"] = df["best_bowling_figure"].apply(lambda x : x.split("--")[0])
df["high_wickets"] = df["high_wickets"].astype(int)
top_bowler = df.groupby("best_bowling")["high_wickets"].sum().sort_values(ascending=False).head(10)
top_bowler
